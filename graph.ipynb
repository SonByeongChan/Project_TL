# %%
import pandas as pd

a = pd.read_csv(r'E:\AI_KDT7\12.Transfer_learning\mini\runs\detect\train\results.csv')
a['metrics/mAP50(B)']
# Out:
# 0     0.00634
# 1     0.13327
# 2     0.21428
# 3     0.39170
# 4     0.35061
#        ...
# 95    0.77611
# 96    0.75866
# 97    0.75630
# 98    0.73882
# 99    0.82775
# Name: metrics/mAP50(B), Length: 100, dtype: float64

# %%
import matplotlib.pyplot as plt

mAP50_values = a['metrics/mAP50(B)']

plt.figure(figsize=(8, 5))
plt.plot(mAP50_values, marker='o', linestyle='-', color='b')
plt.title('mAP50(B) Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('mAP50(B)')
plt.grid(True)
plt.show()
